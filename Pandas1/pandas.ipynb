# %%
import pandas as pd


# series

names = ['tom','jerry','max']
marks=[90,80,100]

# %%
ser1 = pd.Series(data=marks,index=names)

# %%
ser1
# Out:
# tom       90
# jerry     80
# max      100
# dtype: int64

# %%
type(ser1)
# Out:
# pandas.core.series.Series

# %%
ser1.shape
# Out:
# (3,)

# %%
ser1.ndim
# Out:
# 1

# %%
ser2=pd.Series(data=[70,50,30],index=['ras','tan','sam'])

# %%
ser2
# Out:
# ras    70
# tan    50
# sam    30
# dtype: int64

# %%
ser2[1]
# Out:
# 50

# %%
ser2['sam']=90

# %%
ser2['sam']
# Out:
# 90

# %% [markdown]
# ### DataFrame

# %%
dict1 = {'names':['a','b','c'],'age':[30,40,30],'location':['bng','ckm','mys']}

# %%
df = pd.DataFrame(data=dict1,index=[1,2,3])

# %%
df
# Out:
#   names  age location
# 1     a   30      bng
# 2     b   40      ckm
# 3     c   30      mys

# %%
dict2 = {'age':[1,2,3],'place':['tr','pr','cr']}

# %%
df1 = pd.DataFrame(data=dict2,index=[])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16116\1804908914.py in <module>
# ----> 1 df1 = pd.DataFrame(data=dict2,index=[])
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# ...

# %%
df1
# Out:
#    age place
# 0    1    tr
# 1    2    pr
# 2    3    cr

# %%
df1.size
# Out:
# 6

# %%
df1.ndim
# Out:
# 2

# %%
df1.shape
# Out:
# (3, 2)

# %%
df1.loc[0:3,['age','place']]
# Out:
#    age place
# 0    1    tr
# 1    2    pr
# 2    3    cr

# %%
df1.iloc[0:4,0:3]
# Out:
#    age place
# 0    1    tr
# 1    2    pr
# 2    3    cr

# %%
df['names'].values
# Out:
# array(['a', 'b', 'c'], dtype=object)

# %%
df['age'].value_counts()
# Out:
# 30    2
# 40    1
# Name: age, dtype: int64

# %%
df[df['age'].values==30]
# Out:
#   names  age location
# 1     a   30      bng
# 3     c   30      mys

# %%
df[df['age'].values>20]
# Out:
#   names  age location
# 1     a   30      bng
# 2     b   40      ckm
# 3     c   30      mys

# %%
df[['age','location']]
# Out:
#    age location
# 1   30      bng
# 2   40      ckm
# 3   30      mys

# %%
cars = pd.read_csv(r'C:\Users\admin\Downloads\CARS_1.csv')

# %%
cars.head(10)
# Out:
#   name_of_car                    Model    Type  Origin DriveTrain      MSRP  \
# 0       Acura   NSX coupe 2dr manual S  Sports    Asia       Rear  $89,765
# 1       Acura  3.5 RL w/Navigation 4dr   Sedan    Asia      Front  $46,100
# 2       Acura               3.5 RL 4dr   Sedan    Asia      Front  $43,755
# 3       Acura                      MDX     NaN    Asia        All  $36,945
# 4       Acura                   TL 4dr     NaN    Asia      Front  $33,195
# 5       Acura                  TSX 4dr     NaN    Asia      Front  $26,990
# 6       Acura           RSX Type S 2dr     NaN    Asia      Front  $23,820
# 7        Audi                 RS 6 4dr     NaN  Europe      Front  $84,600
# 8        Audi         A8 L Quattro 4dr     NaN  Europe        All  $69,190
# 9        Audi       A6 4.2 Quattro 4dr     NaN  Europe        All  $49,690
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# ...

# %%
cars.tail()
# Out:
#     name_of_car      Model                             Type Origin DriveTrain  \
# 438         NaN        NaN                              NaN    NaN        NaN
# 439         NaN        NaN                              NaN    NaN        NaN
# 440         NaN  group by                1) data will split    NaN        NaN
# 441         NaN        NaN  2) apply the function mean(mpg)    NaN        NaN
# 442         NaN        NaN                       3) combine    NaN        NaN
#
#     MSRP Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 438  NaN     NaN         NaN        NaN         NaN       NaN          NaN
# 439  NaN     NaN         NaN        NaN         NaN       NaN          NaN
# 440  NaN     NaN         NaN        NaN         NaN       NaN          NaN
# 441  NaN     NaN         NaN        NaN         NaN       NaN          NaN
# 442  NaN     NaN         NaN        NaN         NaN       NaN          NaN
#
#      Weight  Wheelbase  Length  Unnamed: 15
# ...

# %%
cars.shape
# Out:
# (443, 16)

# %%
cars.size
# Out:
# 7088

# %%
cars.ndim
# Out:
# 2

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name_of_car  428 non-null    object
#  1   Model        429 non-null    object
#  2   Type         409 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      406 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   343 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
#  15  Unnamed: 15  2 non-null      float64
# dtypes: float64(9), object(7)
# memory usage: 55.5+ KB

# %%
cars.isnull().sum()
# Out:
# name_of_car     15
# Model           14
# Type            34
# Origin          15
# DriveTrain      15
# MSRP            15
# Invoice         37
# EngineSize      15
# Cylinders       17
# Horsepower     100
# MPG_City        15
# MPG_Highway     15
# Weight          15
# Wheelbase       15
# Length          15
# Unnamed: 15    441
# dtype: int64

# %%
cars.describe(include='all')
# Out:
#        name_of_car     Model   Type Origin DriveTrain      MSRP   Invoice  \
# count          428       429    409    428        428       428       406
# unique          38       426      9      3          3       410       403
# top         Toyota  C320 4dr  Sedan   Asia      Front  $21,595   $14,207
# freq            28         2    247    158        226         2         2
# mean           NaN       NaN    NaN    NaN        NaN       NaN       NaN
# std            NaN       NaN    NaN    NaN        NaN       NaN       NaN
# min            NaN       NaN    NaN    NaN        NaN       NaN       NaN
# 25%            NaN       NaN    NaN    NaN        NaN       NaN       NaN
# 50%            NaN       NaN    NaN    NaN        NaN       NaN       NaN
# 75%            NaN       NaN    NaN    NaN        NaN       NaN       NaN
# max            NaN       NaN    NaN    NaN        NaN       NaN       NaN
#
#         EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# ...

# %%
cars['name_of_car'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: name_of_car, dtype: int64

# %%
cars['name_of_car'].value_counts().unique()
# Out:
# array([28, 27, 26, 23, 20, 19, 17, 15, 13, 12, 11,  9,  8,  7,  3,  2,  1],
#       dtype=int64)

# %%
cars['name_of_car'].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
#        'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
#        'Lexus', 'Lincoln', 'Mazda', 'Mercedes-Benz', 'Mercury', 'MINI',
#        'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
#        'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
#        'Volvo', nan], dtype=object)

# %%
cars.sort_values('Weight')
# Out:
#     name_of_car                       Model                             Type  \
# 159       Honda  Insight 2dr (gas/electric)                           Hybrid
# 400      Toyota             Echo 2dr manual                            Sedan
# 399      Toyota                    Echo 4dr                            Sedan
# 398      Toyota               Echo 2dr auto                            Sedan
# 383      Toyota  MR2 Spyder convertible 2dr                           Sports
# ..          ...                         ...                              ...
# 438         NaN                         NaN                              NaN
# 439         NaN                         NaN                              NaN
# 440         NaN                   group by                1) data will split
# 441         NaN                         NaN  2) apply the function mean(mpg)
# 442         NaN                         NaN                       3) combine
#
# ...

# %%
cars.sort_values('Weight',ascending=False)
# Out:
#     name_of_car              Model                             Type Origin  \
# 118        Ford  Excursion 6.8 XLT                              SUV    USA
# 166      Hummer                 H2                              SUV    USA
# 141         GMC  Yukon XL 2500 SLT                              SUV    USA
# 229     Lincoln   Navigator Luxury                              SUV    USA
# 56     Cadillac       Escalade EXT                            Truck    USA
# ..          ...                ...                              ...    ...
# 438         NaN                NaN                              NaN    NaN
# 439         NaN                NaN                              NaN    NaN
# 440         NaN          group by                1) data will split    NaN
# 441         NaN                NaN  2) apply the function mean(mpg)    NaN
# 442         NaN                NaN                       3) combine    NaN
#
# ...

# %%
cars[cars['EngineSize']>3.5]
# Out:
#     name_of_car                  Model   Type  Origin DriveTrain      MSRP  \
# 7          Audi               RS 6 4dr    NaN  Europe      Front  $84,600
# 8          Audi       A8 L Quattro 4dr    NaN  Europe        All  $69,190
# 9          Audi     A6 4.2 Quattro 4dr    NaN  Europe        All  $49,690
# 10         Audi       S4 Avant Quattro    NaN  Europe        All  $49,090
# 11         Audi         S4 Quattro 4dr    NaN  Europe        All  $48,040
# ..          ...                    ...    ...     ...        ...       ...
# 378      Toyota         4Runner SR5 V6    SUV    Asia      Front  $27,710
# 401  Volkswagen        Phaeton W12 4dr  Sedan  Europe      Front  $75,000
# 402  Volkswagen            Phaeton 4dr  Sedan  Europe      Front  $65,000
# 403  Volkswagen              Passat W8  Wagon  Europe      Front  $40,235
# 404  Volkswagen  Passat W8 4MOTION 4dr  Sedan  Europe      Front  $39,235
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars[(cars['EngineSize']<4) | (cars['Weight']>3500)]
# Out:
#     name_of_car                    Model    Type  Origin DriveTrain      MSRP  \
# 0         Acura   NSX coupe 2dr manual S  Sports    Asia       Rear  $89,765
# 1         Acura  3.5 RL w/Navigation 4dr   Sedan    Asia      Front  $46,100
# 2         Acura               3.5 RL 4dr   Sedan    Asia      Front  $43,755
# 3         Acura                      MDX     NaN    Asia        All  $36,945
# 4         Acura                   TL 4dr     NaN    Asia      Front  $33,195
# ..          ...                      ...     ...     ...        ...       ...
# 423       Volvo                     XC70   Wagon  Europe        All  $35,145
# 424       Volvo               S60 T5 4dr   Sedan  Europe      Front  $34,845
# 425       Volvo              S60 2.5 4dr   Sedan  Europe        All  $31,745
# 426       Volvo                      V40   Wagon  Europe      Front  $26,135
# 427       Volvo                  S40 4dr   Sedan  Europe      Front  $25,135
#
# ...

# %%
cars['EngineSize']<4
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 438    False
# 439    False
# 440    False
# 441    False
# 442    False
# Name: EngineSize, Length: 443, dtype: bool

# %%
cars.boxplot(column='Weight')
# Out:
# <AxesSubplot:>

# %%
cars.hist(column='Weight',bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'Weight'}>]], dtype=object)

# %% [markdown]
# ## Crosstab

# %%
pd.crosstab(index=cars['Type'],columns=cars['Weight'])
# Out:
# Weight  1850.0  2035.0  2055.0  2085.0  2195.0  2255.0  2290.0  2339.0  \
# Type
# Hybrid       1       0       0       0       0       0       0       0
# SUV          0       0       0       0       0       0       0       0
# Sedan        0       1       1       1       0       1       1       1
# Sports       0       0       0       0       1       0       0       0
# Truck        0       0       0       0       0       0       0       0
# Wagon        0       0       0       0       0       0       0       0
#
# Weight  2340.0  2348.0  ...  5423.0  5440.0  5464.0  5590.0  5678.0  5879.0  \
# Type                    ...
# Hybrid       0       0  ...       0       0       0       0       0       0
# SUV          0       0  ...       1       0       0       1       0       0
# Sedan        1       1  ...       0       0       0       0       0       0
# Sports       0       0  ...       0       0       0       0       0       0
# ...

# %%
c=pd.crosstab(index=cars['Model'],columns=cars['Weight'])
c.head()
# Out:
# Weight                    1850.0  2035.0  2055.0  2085.0  2195.0  2255.0  \
# Model
# 3.5 RL 4dr                     0       0       0       0       0       0
# 3.5 RL w/Navigation 4dr        0       0       0       0       0       0
# 300M 4dr                       0       0       0       0       0       0
# 300M Special Edition 4dr       0       0       0       0       0       0
# 325Ci 2dr                      0       0       0       0       0       0
#
# Weight                    2290.0  2339.0  2340.0  2348.0  ...  5423.0  5440.0  \
# Model                                                     ...
# 3.5 RL 4dr                     0       0       0       0  ...       0       0
# 3.5 RL w/Navigation 4dr        0       0       0       0  ...       0       0
# 300M 4dr                       0       0       0       0  ...       0       0
# 300M Special Edition 4dr       0       0       0       0  ...       0       0
# ...

# %% [markdown]
# ## Groupby

# %%
list(cars.groupby(["Type",'Cylinders'])['Weight'])
# Out:
# [(('Hybrid', 3.0),
#   159    1850.0
#   Name: Weight, dtype: float64),
#  (('Hybrid', 4.0),
#   156    2732.0
#   388    2890.0
#   Name: Weight, dtype: float64),
#  (('SUV', 4.0),
#   157    3258.0
#   161    3468.0
#   203    3826.0
#   244    3091.0
#   294    3240.0
#   346    3381.0
#   389    3119.0
#   Name: Weight, dtype: float64),
#  (('SUV', 6.0),
#   39     4023.0
#   47     4600.0
#   52     4024.0
#   70     4425.0
#   80     2866.0
#   123    4463.0
#   128    3346.0
#   143    4945.0
#   150    4387.0
#   169    3549.0
#   187    4967.0
#   188    3836.0
#   201    3790.0
#   202    3575.0
#   206    4112.0
#   217    3577.0
#   224    4065.0
#   278    4374.0
#   286    4718.0
#   287    4134.0
#   304    3871.0
#   310    3760.0
#   326    3779.0
#   365    3682.0
#   367    3020.0
#   377    3935.0
#   378    4035.0
#   405    5086.0
#   418    4638.0
#   Name: Weight, dtype: float64),
#  (('SUV', 8.0),
#   30     4824.0
#   57     5367.0
#   60     4302.0
# ...

# %% [markdown]
#  ## pivot table

# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\admin\Downloads\sample_pivot.xlsx')

# %%
df.head()
# Out:
#         Date Region                 Type  Units  Sales
# 0 2020-07-11   East  Children's Clothing   18.0    306
# 1 2020-09-23  North  Children's Clothing   14.0    448
# 2 2020-04-02  South     Women's Clothing   17.0    425
# 3 2020-02-28   East  Children's Clothing   26.0    832
# 4 2020-03-19   West     Women's Clothing    3.0     33

# %%
pivot1 = pd.pivot_table(data=df,index = 'Region')

# %%
pivot1
# Out:
#              Sales      Units
# Region
# East    408.182482  19.732360
# North   438.924051  19.202643
# South   432.956204  20.423358
# West    452.029412  19.294118

# %%
pivot2 = pd.pivot_table(df,index='Region',values='Sales')
pivot2
# Out:
#              Sales
# Region
# East    408.182482
# North   438.924051
# South   432.956204
# West    452.029412

# %%
pivot3 = pd.pivot_table(df,index='Region',values='Sales',aggfunc=['mean','sum'])
pivot3
# Out:
#               mean     sum
#              Sales   Sales
# Region
# East    408.182482  167763
# North   438.924051  138700
# South   432.956204   59315
# West    452.029412   61476
