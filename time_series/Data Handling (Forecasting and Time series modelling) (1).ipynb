# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller,acf,pacf
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# %%
pd.Period('2023-3')
# Out:
# Period('2023-03', 'M')

# %%
pd.Period('2023-3',freq='D')
# Out:
# Period('2023-03-01', 'D')

# %%
pd.Period('2023-3',freq='Y')
# Out:
# Period('2023', 'A-DEC')

# %%
pd.to_datetime(pd.Series(['2023-7-27' ,'2024-4-25',None]))
# Out:
# 0   2023-07-27
# 1   2024-04-25
# 2          NaT
# dtype: datetime64[ns]

# %%
pd.to_datetime('2023/7/25',format='%Y/%m/%d')
# Out:
# Timestamp('2023-07-25 00:00:00')

# %%
air= pd.read_csv(r"C:\Users\admin\Downloads\Air Passengers.csv")

# %%
air
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
air.shape
# Out:
# (144, 1)

# %%
air.size
# Out:
# 144

# %%
air.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
#air['Month']= air['Month'].apply(lambda x: pd.Period(x,'D'))

# %%
#air['Month']

# %%
air
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
air.isna().sum()
# Out:
# Month          0
# #Passengers    0
# dtype: int64

# %%
air.dtypes
# Out:
# Month          object
# #Passengers     int64
# dtype: object

# %%
air.describe()
# Out:
#        #Passengers
# count   144.000000
# mean    280.298611
# std     119.966317
# min     104.000000
# 25%     180.000000
# 50%     265.500000
# 75%     360.500000
# max     622.000000

# %%
air.set_index('Month',inplace=True)
air.index= pd.to_datetime(air.index)
air.dropna(inplace=True)
air.plot()
air.index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20760\1126752764.py in <module>
# ----> 1 air.set_index('Month',inplace=True)
#       2 air.index= pd.to_datetime(air.index)
#       3 air.dropna(inplace=True)
#       4 air.plot()
#       5 air.index
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5501
#    5502         if missing:
# -> 5503             raise KeyError(f"None of {missing} are in the columns")
#    5504
#    5505         if inplace:
#
# KeyError: "None of ['Month'] are in the columns"

# %%
air['#Passengers'].unique()
# Out:
# array([112, 118, 132, 129, 121, 135, 148, 136, 119, 104, 115, 126, 141,
#        125, 149, 170, 158, 133, 114, 140, 145, 150, 178, 163, 172, 199,
#        184, 162, 146, 166, 171, 180, 193, 181, 183, 218, 230, 242, 209,
#        191, 194, 196, 236, 235, 229, 243, 264, 272, 237, 211, 201, 204,
#        188, 227, 234, 302, 293, 259, 203, 233, 267, 269, 270, 315, 364,
#        347, 312, 274, 278, 284, 277, 317, 313, 318, 374, 413, 405, 355,
#        306, 271, 301, 356, 348, 422, 465, 467, 404, 305, 336, 340, 362,
#        363, 435, 491, 505, 359, 310, 337, 360, 342, 406, 396, 420, 472,
#        548, 559, 463, 407, 417, 391, 419, 461, 535, 622, 606, 508, 390,
#        432], dtype=int64)

# %%
result= seasonal_decompose(air['#Passengers'],model='multiplicative')

# %%
result.seasonal.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
result.trend.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
result.resid.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
ts_data= air['#Passengers']

# %%
ts_data_log= np.log(ts_data)

# %%
plt.plot(ts_data_log)

# %%
def test_stationarity(timeseries):
    
    #Calculate rolling mean and rolling standard deviation
    rolmean = timeseries.rolling(window = 12).mean()
    rolstd = timeseries.rolling(window = 12).std()
    
    original = plt.plot(timeseries, color = 'blue', label = 'Original')
    mean = plt.plot(rolmean, color = 'red', label = 'Rolling Mean')
    std = plt.plot(rolstd, color = 'green', label = 'Rolling Std')
    plt.legend(loc='best')
    
    
    print('Results of Dickey-Fuller Test :\n')
    df_test = adfuller(timeseries)
    my_output = pd.Series(df_test[0:4], index =['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for i,j in df_test[4].items():
        my_output['Critical Value (%s)'%i] = j
    print(my_output)

# %%
test_stationarity(air['#Passengers'])
# Out:
# Results of Dickey-Fuller Test :
#
# Test Statistic                   0.815369
# p-value                          0.991880
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %%
movingAverage = ts_data_log.rolling(window = 12).mean()
movingSTD = ts_data_log.rolling(window = 12).std()
plt.plot(ts_data_log)
plt.plot(movingAverage,color='red')

# %%
ts_data_log_diff = ts_data_log - movingAverage
ts_data_log_diff.head(15)
# Out:
# Month
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
# 1949-06-01         NaN
# 1949-07-01         NaN
# 1949-08-01         NaN
# 1949-09-01         NaN
# 1949-10-01         NaN
# 1949-11-01         NaN
# 1949-12-01   -0.065494
# 1950-01-01   -0.093449
# 1950-02-01   -0.007566
# 1950-03-01    0.099416
# Name: #Passengers, dtype: float64

# %%
ts_data_log_diff.dropna(inplace=True)
ts_data_log_diff.head()
# Out:
# Month
# 1949-12-01   -0.065494
# 1950-01-01   -0.093449
# 1950-02-01   -0.007566
# 1950-03-01    0.099416
# 1950-04-01    0.052142
# Name: #Passengers, dtype: float64

# %%
test_stationarity(ts_data_log_diff)
# Out:
# Results of Dickey-Fuller Test :
#
# Test Statistic                  -3.162908
# p-value                          0.022235
# #Lags Used                      13.000000
# Number of Observations Used    119.000000
# Critical Value (1%)             -3.486535
# Critical Value (5%)             -2.886151
# Critical Value (10%)            -2.579896
# dtype: float64

# %%
# Plotting the ACF curve

plt.plot(np.arange(0,11), acf(ts_data_log_diff, nlags = 10))
plt.axhline(y=0, linestyle = '--', color = 'gray')
#Confidence intervals
plt.axhline(y=-1.96/np.sqrt(len(ts_data_log_diff)), linestyle = '--', color = 'green')
plt.axhline(y=1.96/np.sqrt(len(ts_data_log_diff)), linestyle = '--', color = 'green')
plt.title('ACF Plot')
plt.show()

# %%
# Plotting the PACF curve

plt.plot(np.arange(0,11), pacf(ts_data_log_diff, nlags = 10))
plt.axhline(y=0, linestyle = '--', color = 'gray')
#Confidence intervals
plt.axhline(y=-1.96/np.sqrt(len(ts_data_log_diff)), linestyle = '--', color = 'green')
plt.axhline(y=1.96/np.sqrt(len(ts_data_log_diff)), linestyle = '--', color = 'green')
plt.title('PACF Plot')
plt.show()

# %%
model = sm.tsa.arima.ARIMA(ts_data_log, order=(1,3,1))
# Out:
# c:\Users\admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
results = model.fit()

# %%
plt.plot(ts_data_log_diff)
plt.plot(results.fittedvalues,color='red')
plt.show()

# %%
## ti,e stamp j the

# %%
# plotting the ACF curve
plt.plot(np.arange(0,11),acf(ts_data_log_diff,nlags=10))
plt.axhline(y=0,linestyle='----',color ='grey')
##confidence intervals
plt.axhline(y=-1.96/np.sqrt(len(ts_data_log_diff)),linestyle='-----',color = 'green')
plt.axhline(y=1.96/np.sqrt(len(ts_data_log_diff)),linestyle='-----',color = 'green')
plt.title('ACF plot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20760\3876324034.py in <module>
#       1 # plotting the ACF curve
# ----> 2 plt.plot(np.arange(0,11),acf(ts_data_log_diff,nlags=10))
#       3 plt.axhline(y=0,linestyle='----',color ='grey')
#       4 ##confidence intervals
#       5 plt.axhline(y=-1.96/np.sqrt(len(ts_data_log_diff)),linestyle='-----',color = 'green')
#
# NameError: name 'ts_data_log_diff' is not defined
