# %%
import scipy.stats as stats
import pandas as pd

# %%
stat1=stats.uniform.rvs(size=1000,loc=100,scale=80)

# %%
stat_data = pd.DataFrame(stat1)

# %%
stat_data
# Out:
#               0
# 0    131.833551
# 1    160.793259
# 2    154.565010
# 3    123.455951
# 4    125.059372
# ..          ...
# 995  160.062080
# 996  173.572047
# 997  112.398121
# 998  126.404174
# 999  177.550591
#
# [1000 rows x 1 columns]

# %%
stat_data.plot(kind='density',figsize=(10,4))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
stat2=stats.norm.rvs(size=1000,loc=100,scale=80)
stat_data = pd.DataFrame(stat2)
stat_data.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>
