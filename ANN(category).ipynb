# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhilashg11/Data_science/blob/master/ANN(category).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split,GridSearchCV
import keras
import tensorflow
from keras.layers import Dense,Dropout
from keras.datasets import mnist
from keras.models import Sequential
from keras.optimizers import RMSprop
from scikeras.wrappers import kerasClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8de68618d414> in <cell line: 11>()
#       9 from keras.models import Sequential
#      10 from keras.optimizers import RMSprop
# ---> 11 from scikeras.wrappers import kerasClassifier
#
# ModuleNotFoundError: No module named 'scikeras'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df = pd.read_csv('/content/Churn.csv')

# %%
target = df['Exited']

# %%
target
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
features=df.drop(['RowNumber', 'CustomerId', 'Surname','Exited'],axis=1)

# %%
features.Geography.value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
lab_enc = LabelEncoder()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
features['Geography']= lab_enc.fit_transform(features['Geography'])

# %%
features
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0  Female   42       2       0.00              1
# 1             608          2  Female   41       1   83807.86              1
# 2             502          0  Female   42       8  159660.80              3
# 3             699          0  Female   39       1       0.00              2
# 4             850          2  Female   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0    Male   39       5       0.00              2
# 9996          516          0    Male   35      10   57369.61              1
# 9997          709          0  Female   36       7       0.00              1
# 9998          772          1    Male   42       3   75075.31              2
# 9999          792          0  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
pd.get_dummies(features)
# Out:
#       CreditScore  Geography  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0   42       2       0.00              1
# 1             608          2   41       1   83807.86              1
# 2             502          0   42       8  159660.80              3
# 3             699          0   39       1       0.00              2
# 4             850          2   43       2  125510.82              1
# ...           ...        ...  ...     ...        ...            ...
# 9995          771          0   39       5       0.00              2
# 9996          516          0   35      10   57369.61              1
# 9997          709          0   36       7       0.00              1
# 9998          772          1   42       3   75075.31              2
# 9999          792          0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Gender_Female  Gender_Male
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(features,target,train_size=0.75,random_state=100)

# %%
from sklearn.preprocessing import StandardScaler
std_sc = StandardScaler
